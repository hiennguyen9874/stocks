# %%
import os
import sys


ROOT_CRAWL = os.path.join(os.path.dirname("__file__"), "..", "crawl")

# %% [markdown]
# # Load data

# %%
import json

with open(os.path.join(ROOT_CRAWL, 'list_stocks.json'), 'r') as f:
    list_stocks = json.load(f)
list_stocks
# Out:
# {'category': [{'ID': 507331,
#    'CategoryName': 'Danh mục quan tâm',
#    'ListStockCode': ['MBB', 'PVS', 'MBS', 'HCM', 'STB', 'VCI', 'HPG']},
#   {'ID': 2515151,
#    'CategoryName': 'BDS',
#    'ListStockCode': ['DXS',
#     'DXG',
#     'NLG',
#     'KDH',
#     'HDC',
#     'ASM',
#     'HDG',
#     'PDR',
#     'DIG',
#     'VHM',
#     'VIC',
#     'NVL']},
#   {'ID': 2781907,
#    'CategoryName': 'BDS - KCN',
#    'ListStockCode': ['BCM', 'VGC', 'SZC', 'GVR', 'KBC', 'PHR', 'IDC']},
#   {'ID': 2976838,
#    'CategoryName': 'Bán lẻ',
#    'ListStockCode': ['HAX',
#     'PNJ',
#     'PET',
#     'VRE',
#     'VTP',
#     'VNM',
#     'MSN',
#     'FRT',
#     'MWG',
#     'DGW']},
#   {'ID': 2780387,
#    'CategoryName': 'Bảo Hiểm',
#    'ListStockCode': ['MIG', 'BVH', 'BMI']},
#   {'ID': 5642635,
#    'CategoryName': 'Cao su',
#    'ListStockCode': ['DRI', 'DRC', 'DPR', 'PHR', 'GVR']},
#   {'ID': 538592,
#    'CategoryName': 'Chứng Khoán',
#    'ListStockCode': ['VND', 'VCI', 'MBS', 'HCM', 'SHS', 'SSI']},
#   {'ID': 2496227,
#    'CategoryName': 'Cảng Biển & Vận Tải',
#    'ListStockCode': ['SGP', 'HAH', 'GMD']},
#   {'ID': 2496226,
#    'CategoryName': 'Dầu khí',
#    'ListStockCode': ['OIL', 'PLX', 'GAS', 'BSR', 'PVT', 'PVS', 'CNG', 'PVD']},
#   {'ID': 5909534,
#    'CategoryName': 'Dệt may',
#    'ListStockCode': ['GIL', 'MSH', 'TNG', 'VGT']},
#   {'ID': 531811,
#    'CategoryName': 'Ngân Hàng',
#    'ListStockCode': ['LPB',
#     'VIB',
#     'OCB',
#     'HDB',
#     'BID',
#     'VCB',
#     'MSB',
#     'ACB',
#     'CTG',
#     'MBB',
#     'SHB',
#     'STB',
#     'TCB',
#     'TPB',
#     'VPB']},
#   {'ID': 2496229,
#    'CategoryName': 'Phân Bón & Hóa chất',
#    'ListStockCode': ['DGC', 'CSV', 'DPM', 'DCM']},
#   {'ID': 2542066,
#    'CategoryName': 'Thép',
#    'ListStockCode': ['NKG', 'HSG', 'HPG']},
#   {'ID': 2496228,
#    'CategoryName': 'Thủy sản',
#    'ListStockCode': ['CMX', 'ANV', 'ASM', 'FMC', 'VHC']},
#   {'ID': 7697688,
#    'CategoryName': 'Trụ',
#    'ListStockCode': ['PDR',
#     'BVH',
#     'SAB',
#     'FPT',
#     'MBB',
#     'VPB',
#     'CTG',
#     'TCB',
#     'VNM',
#     'MWG',
#     'BID',
#     'NVL',
#     'PLX',
#     'MSN',
#     'GAS',
#     'VCB',
#     'HPG',
#     'VHM',
#     'VIC']},
#   {'ID': 2542069,
#    'CategoryName': 'Xây dựng',
#    'ListStockCode': ['HTN', 'CTD', 'LCG', 'C4G', 'CII', 'CTR', 'HBC']},
#   {'ID': 4820420,
#    'CategoryName': 'Điện gió',
#    'ListStockCode': ['NT2', 'POW', 'PC1', 'FCN', 'GEG', 'REE', 'HDG', 'BCG']},
#   {'ID': 4409158,
#    'CategoryName': 'Đường, thực phẩm, gạo',
#    'ListStockCode': ['HAG', 'TAR', 'LTG', 'DBC', 'KDC', 'PAN', 'SBT']},
#   {'ID': 3228805,
#    'CategoryName': 'Đầu tư công',
#    'ListStockCode': ['FCN',
#     'DHA',
#     'CII',
#     'VCG',
#     'HHV',
#     'KSB',
#     'LCG',
#     'BCC',
#     'HT1',
#     'PC1']}]}

# %%
import pandas as pd

balancesheet = pd.read_csv(os.path.join(ROOT_CRAWL, "balancesheet.csv"), encoding="utf-8")
balancesheet["quarter_start_time"] = balancesheet.apply(
    lambda row: (pd.Period(freq="Q", year=row["year"], quarter=row["quarter"]) + 1).start_time,
    axis=1,
)
balancesheet["quarter_end_time"] = balancesheet.apply(
    lambda row: (pd.Period(freq="Q", year=row["year"], quarter=row["quarter"]) + 1).end_time, axis=1
)
balancesheet
# Out:
#      ticker  quarter  year  shortAsset  cash  shortInvest  shortReceivable  \
# 0       MIG        3  2022      6244.0    46       2105.0            872.0
# 1       MIG        2  2022      6052.0    46       2114.0            784.0
# 2       MIG        1  2022      6272.0    60       2943.0            700.0
# 3       MIG        4  2021      5661.0     9       2987.0            604.0
# 4       MIG        3  2021      4542.0   111       1862.0            773.0
# ...     ...      ...   ...         ...   ...          ...              ...
# 5149    MBS        3  2016      3069.0    42       2487.0            488.0
# 5150    MBS        2  2016      2657.0    42       2088.0            497.0
# 5151    MBS        1  2016      2788.0   177       2074.0            513.0
# 5152    MBS        1  2014      2623.0   924        123.0           1556.0
# 5153    MBS        4  2013      2147.0   711        107.0           1311.0
#
#       inventory  longAsset  fixedAsset  ...  payableInterest  \
# 0           2.0     1986.0          75  ...              NaN
# 1           2.0     2029.0          77  ...              NaN
# 2           2.0     1005.0          79  ...              NaN
# 3           2.0      934.0          81  ...              NaN
# 4           2.0     1812.0          80  ...              NaN
# ...         ...        ...         ...  ...              ...
# 5149        0.0       91.0           7  ...              NaN
# 5150        0.0      191.0           6  ...              NaN
# 5151        0.0       92.0           6  ...              NaN
# 5152        0.0      504.0           8  ...              NaN
# 5153        0.0      503.0           9  ...              NaN
#
#       receivableInterest  deposit  otherDebt  fund  unDistributedIncome  \
# 0                    NaN      NaN        570   NaN                  0.0
# 1                    NaN      NaN        572   NaN                  0.0
# 2                    NaN      NaN        568   NaN                  0.0
# 3                    NaN      NaN        582   NaN                  0.0
# 4                    NaN      NaN        581   NaN                  0.0
# ...                  ...      ...        ...   ...                  ...
# 5149                 NaN      NaN          4   NaN                  NaN
# 5150                 NaN      NaN          4   NaN                  NaN
# 5151                 NaN      NaN          4   NaN                  NaN
# 5152                 NaN      NaN         47   NaN                  NaN
# 5153                 NaN      NaN         15   NaN                  NaN
#
#       minorShareHolderProfit  payable  quarter_start_time  \
# 0                        0.0     6361          2022-10-01
# 1                        0.0     6263          2022-07-01
# 2                        0.0     5462          2022-04-01
# 3                        0.0     4847          2022-01-01
# 4                        0.0     4682          2021-10-01
# ...                      ...      ...                 ...
# 5149                     0.0     1836          2016-10-01
# 5150                     0.0     1529          2016-07-01
# 5151                     0.0     1561          2016-04-01
# 5152                     0.0     1883          2014-04-01
# 5153                     0.0     1427          2014-01-01
#
#                   quarter_end_time
# 0    2022-12-31 23:59:59.999999999
# 1    2022-09-30 23:59:59.999999999
# 2    2022-06-30 23:59:59.999999999
# 3    2022-03-31 23:59:59.999999999
# 4    2021-12-31 23:59:59.999999999
# ...                            ...
# 5149 2016-12-31 23:59:59.999999999
# 5150 2016-09-30 23:59:59.999999999
# 5151 2016-06-30 23:59:59.999999999
# 5152 2014-06-30 23:59:59.999999999
# 5153 2014-03-31 23:59:59.999999999
#
# [5154 rows x 39 columns]

# %%
financialratio = pd.read_csv(os.path.join(ROOT_CRAWL, "financialratio.csv"), encoding="utf-8")
financialratio["quarter_start_time"] = financialratio.apply(
    lambda row: (pd.Period(freq="Q", year=row["year"], quarter=row["quarter"]) + 1).start_time,
    axis=1,
)
financialratio["quarter_end_time"] = financialratio.apply(
    lambda row: (pd.Period(freq="Q", year=row["year"], quarter=row["quarter"]) + 1).end_time, axis=1
)
financialratio
# Out:
#      ticker  quarter  year  priceToEarning  priceToBook  valueBeforeEbitda  \
# 0       MIG        3  2022            13.1          1.5               -5.3
# 1       MIG        2  2022            20.5          2.2               -4.8
# 2       MIG        1  2022            14.8          2.1               -8.7
# 3       MIG        4  2021            15.2          2.0               -8.8
# 4       MIG        3  2021            15.1          2.2               -6.6
# ...     ...      ...   ...             ...          ...                ...
# 4460    MBS        2  2018            17.6          1.7                9.9
# 4461    MBS        1  2018            34.0          2.2                9.3
# 4462    MBS        4  2017            95.5          1.8               11.9
# 4463    MBS        3  2017            96.5          1.5               11.3
# 4464    MBS        2  2017            83.3          1.1                7.7
#
#       dividend    roe    roa  daysReceivable  ...  depositOnEarnAsset  \
# 0          NaN  0.119  0.029             NaN  ...                 NaN
# 1          NaN  0.111  0.027             NaN  ...                 NaN
# 2          NaN  0.151  0.040             NaN  ...                 NaN
# 3          NaN  0.137  0.037             NaN  ...                 NaN
# 4          NaN  0.157  0.042             NaN  ...                 NaN
# ...        ...    ...    ...             ...  ...                 ...
# 4460       NaN  0.100  0.034             NaN  ...                 NaN
# 4461       NaN  0.065  0.021             NaN  ...                 NaN
# 4462       NaN  0.018  0.006             NaN  ...                 NaN
# 4463       NaN  0.015  0.005             NaN  ...                 NaN
# 4464       NaN  0.014  0.005             NaN  ...                 NaN
#
#       badDebtOnAsset  liquidityOnLiability  payableOnEquity  cancelDebt  \
# 0                NaN                   NaN              3.4         NaN
# 1                NaN                   NaN              3.4         NaN
# 2                NaN                   NaN              3.0         NaN
# 3                NaN                   NaN              2.8         NaN
# 4                NaN                   NaN              2.8         NaN
# ...              ...                   ...              ...         ...
# 4460             NaN                   NaN              1.8         NaN
# 4461             NaN                   NaN              2.3         NaN
# 4462             NaN                   NaN              2.3         NaN
# 4463             NaN                   NaN              2.2         NaN
# 4464             NaN                   NaN              2.1         NaN
#
#       ebitdaOnStockChange  bookValuePerShareChange  creditGrowth  \
# 0                   0.007                    0.028           NaN
# 1                  -0.021                    0.002           NaN
# 2                   0.033                    0.039           NaN
# 3                   0.033                    0.045           NaN
# 4                  -0.027                    0.020           NaN
# ...                   ...                      ...           ...
# 4460                0.231                    0.040           NaN
# 4461                0.358                    0.055           NaN
# 4462                0.099                    0.004           NaN
# 4463                0.154                   -0.041           NaN
# 4464                0.200                    0.001           NaN
#
#       quarter_start_time              quarter_end_time
# 0             2022-10-01 2022-12-31 23:59:59.999999999
# 1             2022-07-01 2022-09-30 23:59:59.999999999
# 2             2022-04-01 2022-06-30 23:59:59.999999999
# 3             2022-01-01 2022-03-31 23:59:59.999999999
# 4             2021-10-01 2021-12-31 23:59:59.999999999
# ...                  ...                           ...
# 4460          2018-07-01 2018-09-30 23:59:59.999999999
# 4461          2018-04-01 2018-06-30 23:59:59.999999999
# 4462          2018-01-01 2018-03-31 23:59:59.999999999
# 4463          2017-10-01 2017-12-31 23:59:59.999999999
# 4464          2017-07-01 2017-09-30 23:59:59.999999999
#
# [4465 rows x 61 columns]

# %%
incomestatement = pd.read_csv(os.path.join(ROOT_CRAWL, "incomestatement.csv"), encoding="utf-8")
incomestatement["quarter_start_time"] = incomestatement.apply(
    lambda row: (pd.Period(freq="Q", year=row["year"], quarter=row["quarter"]) + 1).start_time,
    axis=1,
)
incomestatement["quarter_end_time"] = incomestatement.apply(
    lambda row: (pd.Period(freq="Q", year=row["year"], quarter=row["quarter"]) + 1).end_time, axis=1
)
incomestatement.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5397 entries, 0 to 5396
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ticker                          5397 non-null   object
#  1   quarter                         5397 non-null   int64
#  2   year                            5397 non-null   int64
#  3   revenue                         5397 non-null   int64
#  4   yearRevenueGrowth               4668 non-null   float64
#  5   quarterRevenueGrowth            4967 non-null   float64
#  6   costOfGoodSold                  4677 non-null   float64
#  7   grossProfit                     4677 non-null   float64
#  8   operationExpense                5296 non-null   float64
#  9   operationProfit                 5296 non-null   float64
#  10  yearOperationProfitGrowth       4080 non-null   float64
#  11  quarterOperationProfitGrowth    4376 non-null   float64
#  12  interestExpense                 4421 non-null   float64
#  13  preTaxProfit                    5397 non-null   int64
#  14  postTaxProfit                   5397 non-null   int64
#  15  shareHolderIncome               5397 non-null   int64
#  16  yearShareHolderIncomeGrowth     4248 non-null   float64
#  17  quarterShareHolderIncomeGrowth  4540 non-null   float64
#  18  investProfit                    720 non-null    float64
#  19  serviceProfit                   720 non-null    float64
#  20  otherProfit                     720 non-null    float64
#  21  provisionExpense                720 non-null    float64
#  22  operationIncome                 720 non-null    float64
#  23  ebitda                          3784 non-null   float64
#  24  quarter_start_time              5397 non-null   datetime64[ns]
#  25  quarter_end_time                5397 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), float64(17), int64(6), object(1)
# memory usage: 1.1+ MB

# %%
prices = pd.read_csv(os.path.join(ROOT_CRAWL, "prices.csv"), encoding="utf-8")
prices["date"] = pd.to_datetime(prices["date"])
prices
# Out:
#         index       date  adjust  close  change_perc        avg  volume_match  \
# 0        1394 2017-05-05   8.273   14.0      40.0000  13.970000       89600.0
# 1        1393 2017-05-08   8.863   15.0       7.1429  15.187000      215650.0
# 2        1392 2017-05-09   8.273   14.0      -7.8947  14.143000       39560.0
# 3        1391 2017-05-10   8.213   13.9      -1.4184  13.496000      100260.0
# 4        1390 2017-05-11   8.036   13.6       0.7407  13.574000       47020.0
# ...       ...        ...     ...    ...          ...        ...           ...
# 222141      4 2022-11-28  13.500   13.5       9.7561  13.312288     2365884.0
# 222142      3 2022-11-29  13.800   13.8       2.2222  13.586000     4142748.0
# 222143      2 2022-11-30  13.900   13.9       0.7246  13.685000     2790411.0
# 222144      1 2022-12-01  13.300   13.3      -4.3165  13.908000     4325145.0
# 222145      0 2022-12-02  14.600   14.6       9.7744  13.797000     4640128.0
#
#          value_match  volume_reconcile  value_reconcile  open  high   low  \
# 0       1.251700e+09               0.0              0.0  14.0  14.0  12.9
# 1       3.275045e+09               0.0              0.0  16.0  16.0  14.5
# 2       5.595600e+08               0.0              0.0  15.3  15.3  14.0
# 3       1.353085e+09               0.0              0.0  14.1  14.1  13.0
# 4       6.382600e+08               0.0              0.0  13.5  14.0  13.4
# ...              ...               ...              ...   ...   ...   ...
# 222141  2.365884e+06               0.0              0.0  12.7  13.5  12.6
# 222142  5.628226e+10               0.0              0.0  13.3  14.2  12.8
# 222143  3.818578e+10               0.0              0.0  12.5  14.2  12.5
# 222144  6.015435e+10               0.0              0.0  14.0  14.4  13.2
# 222145  6.401732e+10               0.0              0.0  13.3  14.6  12.8
#
#        symbol     volume
# 0         MIG    89600.0
# 1         MIG   215650.0
# 2         MIG    39560.0
# 3         MIG   100260.0
# 4         MIG    47020.0
# ...       ...        ...
# 222141    MBS  2365884.0
# 222142    MBS  4142748.0
# 222143    MBS  2790411.0
# 222144    MBS  4325145.0
# 222145    MBS  4640128.0
#
# [222146 rows x 15 columns]

# %% [markdown]
# # Price and financialratio

# %%
[x["CategoryName"] for x in list_stocks["category"]]
# Out:
# ['Danh mục quan tâm',
#  'BDS',
#  'BDS - KCN',
#  'Bán lẻ',
#  'Bảo Hiểm',
#  'Cao su',
#  'Chứng Khoán',
#  'Cảng Biển & Vận Tải',
#  'Dầu khí',
#  'Dệt may',
#  'Ngân Hàng',
#  'Phân Bón & Hóa chất',
#  'Thép',
#  'Thủy sản',
#  'Trụ',
#  'Xây dựng',
#  'Điện gió',
#  'Đường, thực phẩm, gạo',
#  'Đầu tư công']

# %%
# symbols = list(filter(lambda x: x["CategoryName"] == "Ngân Hàng", list_stocks["category"]))[0][
#     "ListStockCode"
# ]
symbols = ["ACB"]
assert len(symbols) == 1

# %%
price_financialratio = pd.merge(
    prices[prices["symbol"].isin(symbols)],
    financialratio[financialratio["ticker"].isin(symbols)],
    left_on="symbol",
    right_on="ticker",
    how="inner",
)
price_financialratio = price_financialratio[
    (price_financialratio["date"] >= price_financialratio["quarter_start_time"])
    & (price_financialratio["date"] <= price_financialratio["quarter_end_time"])
]
if len(symbols) == 1:
    price_financialratio = price_financialratio.drop_duplicates(subset="date", keep="first")
price_financialratio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2472 entries, 39 to 148260
# Data columns (total 76 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   index                    2472 non-null   int64
#  1   date                     2472 non-null   datetime64[ns]
#  2   adjust                   2472 non-null   float64
#  3   close                    2472 non-null   float64
#  4   change_perc              2472 non-null   float64
#  5   avg                      2472 non-null   float64
#  6   volume_match             2472 non-null   float64
#  7   value_match              2472 non-null   float64
#  8   volume_reconcile         2472 non-null   float64
#  9   value_reconcile          2472 non-null   float64
#  10  open                     2472 non-null   float64
#  11  high                     2472 non-null   float64
#  12  low                      2472 non-null   float64
#  13  symbol                   2472 non-null   object
#  14  volume                   2472 non-null   float64
#  15  ticker                   2472 non-null   object
#  16  quarter                  2472 non-null   int64
#  17  year                     2472 non-null   int64
#  18  priceToEarning           1919 non-null   float64
#  19  priceToBook              1919 non-null   float64
#  20  valueBeforeEbitda        0 non-null      float64
#  21  dividend                 0 non-null      float64
#  22  roe                      2472 non-null   float64
#  23  roa                      2472 non-null   float64
#  24  daysReceivable           0 non-null      float64
#  25  daysInventory            0 non-null      float64
#  26  daysPayable              0 non-null      float64
#  27  ebitOnInterest           0 non-null      float64
#  28  earningPerShare          2472 non-null   float64
#  29  bookValuePerShare        2472 non-null   float64
#  30  interestMargin           2472 non-null   float64
#  31  nonInterestOnToi         2472 non-null   float64
#  32  badDebtPercentage        2472 non-null   float64
#  33  provisionOnBadDebt       2472 non-null   float64
#  34  costOfFinancing          2472 non-null   float64
#  35  equityOnTotalAsset       2472 non-null   float64
#  36  equityOnLoan             2472 non-null   float64
#  37  costToIncome             2472 non-null   float64
#  38  equityOnLiability        2472 non-null   float64
#  39  currentPayment           0 non-null      float64
#  40  quickPayment             0 non-null      float64
#  41  epsChange                2472 non-null   float64
#  42  ebitdaOnStock            0 non-null      float64
#  43  grossProfitMargin        0 non-null      float64
#  44  operatingProfitMargin    0 non-null      float64
#  45  postTaxMargin            0 non-null      float64
#  46  debtOnEquity             0 non-null      float64
#  47  debtOnAsset              0 non-null      float64
#  48  debtOnEbitda             0 non-null      float64
#  49  shortOnLongDebt          0 non-null      float64
#  50  assetOnEquity            2472 non-null   float64
#  51  capitalBalance           0 non-null      float64
#  52  cashOnEquity             0 non-null      float64
#  53  cashOnCapitalize         0 non-null      float64
#  54  cashCirculation          0 non-null      float64
#  55  revenueOnWorkCapital     0 non-null      float64
#  56  capexOnFixedAsset        0 non-null      float64
#  57  revenueOnAsset           0 non-null      float64
#  58  postTaxOnPreTax          0 non-null      float64
#  59  ebitOnRevenue            0 non-null      float64
#  60  preTaxOnEbit             0 non-null      float64
#  61  preProvisionOnToi        2472 non-null   float64
#  62  postTaxOnToi             2472 non-null   float64
#  63  loanOnEarnAsset          2472 non-null   float64
#  64  loanOnAsset              2472 non-null   float64
#  65  loanOnDeposit            2472 non-null   float64
#  66  depositOnEarnAsset       2472 non-null   float64
#  67  badDebtOnAsset           2472 non-null   float64
#  68  liquidityOnLiability     2472 non-null   float64
#  69  payableOnEquity          2472 non-null   float64
#  70  cancelDebt               2472 non-null   float64
#  71  ebitdaOnStockChange      0 non-null      float64
#  72  bookValuePerShareChange  2472 non-null   float64
#  73  creditGrowth             2472 non-null   float64
#  74  quarter_start_time       2472 non-null   datetime64[ns]
#  75  quarter_end_time         2472 non-null   datetime64[ns]
# dtypes: datetime64[ns](3), float64(68), int64(3), object(2)
# memory usage: 1.5+ MB

# %% [markdown]
# ## P/E & P/B

# %%
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go


price_financialratio["pe"] = (
    price_financialratio["close"] * 1000 / price_financialratio["earningPerShare"]
)
# sns.lineplot(data=price_financialratio, x="date", y="pe", hue="symbol")
fig = px.line(price_financialratio, x="date", y="pe", color="symbol")
# fig.update_layout(yaxis_range=[0,100])
fig.show()

# %%
if len(symbols) == 1:
    print(
        price_financialratio[
            (price_financialratio["date"] > "2022-07-01")
            & (price_financialratio["date"] < "2022-12-01")
        ]["pe"].min()
    )
# Out:
# 4.463147156337669

# %%
price_financialratio["pb"] = (
    price_financialratio["close"] * 1000 / price_financialratio["bookValuePerShare"]
)
# sns.lineplot(data=price_financialratio, x="date", y="pb", hue="symbol")
fig = px.line(price_financialratio, x="date", y="pb", color='symbol')
fig.show()

# %%
if len(symbols) == 1:
    fair_pb = 1.7
    filtered_date = price_financialratio[
        (price_financialratio["date"] > "2022-07-01")
        & (price_financialratio["date"] < "2022-12-01")
    ]
    row = filtered_date.loc[filtered_date["pb"].idxmin()]

    print("Giá fair:", ((fair_pb) / row["pb"]) * row["close"])
    print("Tăng % từ đáy: ", ((fair_pb - row["pb"]) / row["pb"]) * 100)
# Out:
# Giá fair: 28.0534
# Tăng % từ đáy:  60.30514285714285
