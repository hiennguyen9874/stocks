# %%
import os
import sys


ROOT_CRAWL = os.path.join(os.path.dirname("__file__"), "..", "crawl")

# %% [markdown]
# # Load data

# %%
import json

with open(os.path.join(ROOT_CRAWL, 'list_stocks.json'), 'r') as f:
    list_stocks = json.load(f)
list_stocks
# Out:
# {'category': [{'ID': 507331,
#    'CategoryName': 'Danh mục quan tâm',
#    'ListStockCode': ['MBB', 'PVS', 'MBS', 'HCM', 'STB', 'VCI', 'HPG']},
#   {'ID': 2515151,
#    'CategoryName': 'BDS',
#    'ListStockCode': ['DXS',
#     'DXG',
#     'NLG',
#     'KDH',
#     'HDC',
#     'ASM',
#     'HDG',
#     'PDR',
#     'DIG',
#     'VHM',
#     'VIC',
#     'NVL']},
#   {'ID': 2781907,
#    'CategoryName': 'BDS - KCN',
#    'ListStockCode': ['BCM', 'VGC', 'SZC', 'GVR', 'KBC', 'PHR', 'IDC']},
#   {'ID': 2976838,
#    'CategoryName': 'Bán lẻ',
#    'ListStockCode': ['HAX',
#     'PNJ',
#     'PET',
#     'VRE',
#     'VTP',
#     'VNM',
#     'MSN',
#     'FRT',
#     'MWG',
#     'DGW']},
#   {'ID': 2780387,
#    'CategoryName': 'Bảo Hiểm',
#    'ListStockCode': ['MIG', 'BVH', 'BMI']},
#   {'ID': 5642635,
#    'CategoryName': 'Cao su',
#    'ListStockCode': ['DRI', 'DRC', 'DPR', 'PHR', 'GVR']},
#   {'ID': 538592,
#    'CategoryName': 'Chứng Khoán',
#    'ListStockCode': ['VND', 'VCI', 'MBS', 'HCM', 'SHS', 'SSI']},
#   {'ID': 2496227,
#    'CategoryName': 'Cảng Biển & Vận Tải',
#    'ListStockCode': ['SGP', 'HAH', 'GMD']},
#   {'ID': 2496226,
#    'CategoryName': 'Dầu khí',
#    'ListStockCode': ['OIL', 'PLX', 'GAS', 'BSR', 'PVT', 'PVS', 'CNG', 'PVD']},
#   {'ID': 5909534,
#    'CategoryName': 'Dệt may',
#    'ListStockCode': ['GIL', 'MSH', 'TNG', 'VGT']},
#   {'ID': 531811,
#    'CategoryName': 'Ngân Hàng',
#    'ListStockCode': ['LPB',
#     'VIB',
#     'OCB',
#     'HDB',
#     'BID',
#     'VCB',
#     'MSB',
#     'ACB',
#     'CTG',
#     'MBB',
#     'SHB',
#     'STB',
#     'TCB',
#     'TPB',
#     'VPB']},
#   {'ID': 2496229,
#    'CategoryName': 'Phân Bón & Hóa chất',
#    'ListStockCode': ['DGC', 'CSV', 'DPM', 'DCM']},
#   {'ID': 2542066,
#    'CategoryName': 'Thép',
#    'ListStockCode': ['NKG', 'HSG', 'HPG']},
#   {'ID': 2496228,
#    'CategoryName': 'Thủy sản',
#    'ListStockCode': ['CMX', 'ANV', 'ASM', 'FMC', 'VHC']},
#   {'ID': 7697688,
#    'CategoryName': 'Trụ',
#    'ListStockCode': ['PDR',
#     'BVH',
#     'SAB',
#     'FPT',
#     'MBB',
#     'VPB',
#     'CTG',
#     'TCB',
#     'VNM',
#     'MWG',
#     'BID',
#     'NVL',
#     'PLX',
#     'MSN',
#     'GAS',
#     'VCB',
#     'HPG',
#     'VHM',
#     'VIC']},
#   {'ID': 2542069,
#    'CategoryName': 'Xây dựng',
#    'ListStockCode': ['HTN', 'CTD', 'LCG', 'C4G', 'CII', 'CTR', 'HBC']},
#   {'ID': 4820420,
#    'CategoryName': 'Điện gió',
#    'ListStockCode': ['NT2', 'POW', 'PC1', 'FCN', 'GEG', 'REE', 'HDG', 'BCG']},
#   {'ID': 4409158,
#    'CategoryName': 'Đường, thực phẩm, gạo',
#    'ListStockCode': ['HAG', 'TAR', 'LTG', 'DBC', 'KDC', 'PAN', 'SBT']},
#   {'ID': 3228805,
#    'CategoryName': 'Đầu tư công',
#    'ListStockCode': ['FCN',
#     'DHA',
#     'CII',
#     'VCG',
#     'HHV',
#     'KSB',
#     'LCG',
#     'BCC',
#     'HT1',
#     'PC1']}]}

# %%
import pandas as pd

balancesheet = pd.read_csv(os.path.join(ROOT_CRAWL, "balancesheet.csv"), encoding="utf-8")
balancesheet["quarter_start_time"] = balancesheet.apply(
    lambda row: (pd.Period(freq="Q", year=row["year"], quarter=row["quarter"]) + 1).start_time,
    axis=1,
)
balancesheet["quarter_end_time"] = balancesheet.apply(
    lambda row: (pd.Period(freq="Q", year=row["year"], quarter=row["quarter"]) + 1).end_time, axis=1
)
balancesheet
# Out:
#      ticker  quarter  year  shortAsset  cash  shortInvest  shortReceivable  \
# 0       IDC        3  2022      4565.0   460       1832.0           1638.0
# 1       IDC        2  2022      4337.0   512       1860.0           1316.0
# 2       IDC        1  2022      4518.0   553       2058.0           1262.0
# 3       IDC        4  2021      4368.0   495       2169.0           1096.0
# 4       IDC        3  2021      4171.0   786       1989.0            765.0
# ...     ...      ...   ...         ...   ...          ...              ...
# 5149    MBB        1  2012         NaN   830          NaN              NaN
# 5150    MBB        4  2011         NaN   917          NaN              NaN
# 5151    MBB        3  2011         NaN   841          NaN              NaN
# 5152    MBB        2  2011         NaN   819          NaN              NaN
# 5153    MBB        1  2011         NaN   846          NaN              NaN
#
#       inventory  longAsset  fixedAsset  ...  payableInterest  \
# 0         506.0    11650.0        5068  ...              NaN
# 1         557.0    11914.0        5191  ...              NaN
# 2         567.0    11742.0        5359  ...              NaN
# 3         549.0    11884.0        5821  ...              NaN
# 4         577.0    11930.0        5943  ...              NaN
# ...         ...        ...         ...  ...              ...
# 5149        NaN        NaN        1558  ...           1085.0
# 5150        NaN        NaN        1552  ...           1074.0
# 5151        NaN        NaN        1564  ...           1074.0
# 5152        NaN        NaN        1462  ...            905.0
# 5153        NaN        NaN        1230  ...            826.0
#
#       receivableInterest  deposit  otherDebt   fund  unDistributedIncome  \
# 0                    NaN      NaN        314    NaN                  0.0
# 1                    NaN      NaN        174    NaN                  0.0
# 2                    NaN      NaN        154    NaN                  0.0
# 3                    NaN      NaN        390    NaN                  0.0
# 4                    NaN      NaN        461    NaN                  0.0
# ...                  ...      ...        ...    ...                  ...
# 5149              2192.0  94818.0       5530  870.0               1928.0
# 5150              2050.0  88993.0       4532  850.0               2432.0
# 5151              1527.0  76509.0       3574  922.0               1611.0
# 5152              1440.0  72685.0       5059  977.0               1001.0
# 5153              1280.0  71703.0       4782  586.0               1275.0
#
#       minorShareHolderProfit  payable  quarter_start_time  \
# 0                     1222.0     9863          2022-10-01
# 1                     1176.0     9691          2022-07-01
# 2                     1157.0    10947          2022-04-01
# 3                     1128.0    11215          2022-01-01
# 4                      813.0    11234          2021-10-01
# ...                      ...      ...                 ...
# 5149                     0.0   130865          2012-04-01
# 5150                     0.0   127062          2012-01-01
# 5151                     0.0   104123          2011-10-01
# 5152                     0.0   104852          2011-07-01
# 5153                     0.0   108075          2011-04-01
#
#                   quarter_end_time
# 0    2022-12-31 23:59:59.999999999
# 1    2022-09-30 23:59:59.999999999
# 2    2022-06-30 23:59:59.999999999
# 3    2022-03-31 23:59:59.999999999
# 4    2021-12-31 23:59:59.999999999
# ...                            ...
# 5149 2012-06-30 23:59:59.999999999
# 5150 2012-03-31 23:59:59.999999999
# 5151 2011-12-31 23:59:59.999999999
# 5152 2011-09-30 23:59:59.999999999
# 5153 2011-06-30 23:59:59.999999999
#
# [5154 rows x 39 columns]

# %%
financialratio = pd.read_csv(os.path.join(ROOT_CRAWL, "financialratio.csv"), encoding="utf-8")
financialratio["quarter_start_time"] = financialratio.apply(
    lambda row: (pd.Period(freq="Q", year=row["year"], quarter=row["quarter"]) + 1).start_time,
    axis=1,
)
financialratio["quarter_end_time"] = financialratio.apply(
    lambda row: (pd.Period(freq="Q", year=row["year"], quarter=row["quarter"]) + 1).end_time, axis=1
)
financialratio
# Out:
#      ticker  quarter  year  priceToEarning  priceToBook  valueBeforeEbitda  \
# 0       IDC        3  2022             5.6          2.3                3.9
# 1       IDC        2  2022             8.7          3.0                5.7
# 2       IDC        1  2022            35.1          5.5               16.9
# 3       IDC        4  2021            46.1          5.3               22.9
# 4       IDC        3  2021            26.2          3.5               26.8
# ...     ...      ...   ...             ...          ...                ...
# 4460    MBB        2  2013             NaN          NaN                NaN
# 4461    MBB        1  2013             NaN          NaN                NaN
# 4462    MBB        4  2012             NaN          NaN                NaN
# 4463    MBB        3  2012             NaN          NaN                NaN
# 4464    MBB        2  2012             NaN          NaN                NaN
#
#       dividend    roe    roa  daysReceivable  ...  depositOnEarnAsset  \
# 0          NaN  0.458  0.130            98.0  ...                 NaN
# 1          NaN  0.399  0.117           124.0  ...                 NaN
# 2          NaN  0.167  0.042           148.0  ...                 NaN
# 3          NaN  0.121  0.029           142.0  ...                 NaN
# 4          NaN  0.143  0.036           170.0  ...                 NaN
# ...        ...    ...    ...             ...  ...                 ...
# 4460       NaN  0.165  0.014             NaN  ...               0.838
# 4461       NaN  0.166  0.014             NaN  ...               0.780
# 4462       NaN  0.195  0.015             NaN  ...               0.715
# 4463       NaN  0.234  0.021             NaN  ...               0.738
# 4464       NaN  0.237  0.020             NaN  ...               0.726
#
#       badDebtOnAsset  liquidityOnLiability  payableOnEquity  cancelDebt  \
# 0                NaN                   NaN              1.6         NaN
# 1                NaN                   NaN              1.5         NaN
# 2                NaN                   NaN              2.1         NaN
# 3                NaN                   NaN              2.2         NaN
# 4                NaN                   NaN              2.3         NaN
# ...              ...                   ...              ...         ...
# 4460           0.011                 0.538             11.0       0.025
# 4461           0.010                 0.574             11.0       0.026
# 4462           0.008                 0.574             12.6       0.027
# 4463           0.009                 0.556              9.7       0.012
# 4464           0.013                 0.551             10.5       0.015
#
#       ebitdaOnStockChange  bookValuePerShareChange  creditGrowth  \
# 0                   0.234                   -0.047           NaN
# 1                   1.080                    0.296           NaN
# 2                   0.732                    0.063           NaN
# 3                  -0.027                   -0.036           NaN
# 4                  -0.049                    0.041           NaN
# ...                   ...                      ...           ...
# 4460                  NaN                    0.022         0.217
# 4461                  NaN                    0.096         0.201
# 4462                  NaN                   -0.058         0.261
# 4463                  NaN                    0.049         0.158
# 4464                  NaN                   -0.007         0.210
#
#       quarter_start_time              quarter_end_time
# 0             2022-10-01 2022-12-31 23:59:59.999999999
# 1             2022-07-01 2022-09-30 23:59:59.999999999
# 2             2022-04-01 2022-06-30 23:59:59.999999999
# 3             2022-01-01 2022-03-31 23:59:59.999999999
# 4             2021-10-01 2021-12-31 23:59:59.999999999
# ...                  ...                           ...
# 4460          2013-07-01 2013-09-30 23:59:59.999999999
# 4461          2013-04-01 2013-06-30 23:59:59.999999999
# 4462          2013-01-01 2013-03-31 23:59:59.999999999
# 4463          2012-10-01 2012-12-31 23:59:59.999999999
# 4464          2012-07-01 2012-09-30 23:59:59.999999999
#
# [4465 rows x 61 columns]

# %%
incomestatement = pd.read_csv(os.path.join(ROOT_CRAWL, "incomestatement.csv"), encoding="utf-8")
incomestatement["quarter_start_time"] = incomestatement.apply(
    lambda row: (pd.Period(freq="Q", year=row["year"], quarter=row["quarter"]) + 1).start_time,
    axis=1,
)
incomestatement["quarter_end_time"] = incomestatement.apply(
    lambda row: (pd.Period(freq="Q", year=row["year"], quarter=row["quarter"]) + 1).end_time, axis=1
)
incomestatement.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5397 entries, 0 to 5396
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ticker                          5397 non-null   object
#  1   quarter                         5397 non-null   int64
#  2   year                            5397 non-null   int64
#  3   revenue                         5397 non-null   int64
#  4   yearRevenueGrowth               4668 non-null   float64
#  5   quarterRevenueGrowth            4967 non-null   float64
#  6   costOfGoodSold                  4677 non-null   float64
#  7   grossProfit                     4677 non-null   float64
#  8   operationExpense                5296 non-null   float64
#  9   operationProfit                 5296 non-null   float64
#  10  yearOperationProfitGrowth       4080 non-null   float64
#  11  quarterOperationProfitGrowth    4376 non-null   float64
#  12  interestExpense                 4421 non-null   float64
#  13  preTaxProfit                    5397 non-null   int64
#  14  postTaxProfit                   5397 non-null   int64
#  15  shareHolderIncome               5397 non-null   int64
#  16  yearShareHolderIncomeGrowth     4248 non-null   float64
#  17  quarterShareHolderIncomeGrowth  4540 non-null   float64
#  18  investProfit                    720 non-null    float64
#  19  serviceProfit                   720 non-null    float64
#  20  otherProfit                     720 non-null    float64
#  21  provisionExpense                720 non-null    float64
#  22  operationIncome                 720 non-null    float64
#  23  ebitda                          3784 non-null   float64
#  24  quarter_start_time              5397 non-null   datetime64[ns]
#  25  quarter_end_time                5397 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), float64(17), int64(6), object(1)
# memory usage: 1.1+ MB

# %%
prices = pd.read_csv(os.path.join(ROOT_CRAWL, "prices.csv"), encoding="utf-8")
prices["date"] = pd.to_datetime(prices["date"])
prices
# Out:
#         index       date  adjust  close  change_perc     avg  volume_match  \
# 0        1254 2017-11-24  22.675   28.5      19.2469  28.530      547500.0
# 1        1253 2017-11-27  23.391   29.4       3.1579  29.143      131259.0
# 2        1252 2017-11-28  22.913   28.8      -1.0309  28.865       66000.0
# 3        1251 2017-11-29  21.879   27.5      -4.8443  27.684      173400.0
# 4        1250 2017-11-30  22.675   28.5       2.8881  27.919      134200.0
# ...       ...        ...     ...    ...          ...     ...           ...
# 222585      4 2022-12-02  18.800   18.8       5.6180  18.150    16329100.0
# 222586      3 2022-12-05  19.000   19.0       1.0638  19.030    19932400.0
# 222587      2 2022-12-06  17.700   17.7      -6.8421  18.340    22074300.0
# 222588      1 2022-12-07  17.300   17.3      -2.2599  17.510    12155000.0
# 222589      0 2022-12-08  18.100   18.1       4.6243  18.150    13815500.0
#
#          value_match  volume_reconcile  value_reconcile   open   high    low  \
# 0       1.562021e+10               0.0     0.000000e+00  27.90  29.50  27.90
# 1       3.825269e+09               0.0     0.000000e+00  29.50  29.50  28.70
# 2       1.905100e+09               0.0     0.000000e+00  29.10  29.10  28.70
# 3       4.800400e+09               0.0     0.000000e+00  28.80  28.80  27.00
# 4       3.746690e+09               0.0     0.000000e+00  27.50  28.70  27.20
# ...              ...               ...              ...    ...    ...    ...
# 222585  2.964248e+11               0.0     0.000000e+00  17.80  18.80  17.55
# 222586  3.793804e+11               0.0     0.000000e+00  19.00  19.30  18.75
# 222587  4.048810e+11           65000.0     1.267500e+09  19.00  19.05  17.70
# 222588  2.128125e+11          485000.0     8.962500e+09  17.65  17.90  17.25
# 222589  2.507640e+11          432000.0     7.766500e+09  17.70  18.50  17.55
#
#        symbol      volume
# 0         IDC    547500.0
# 1         IDC    131259.0
# 2         IDC     66000.0
# 3         IDC    173400.0
# 4         IDC    134200.0
# ...       ...         ...
# 222585    MBB  16329100.0
# 222586    MBB  19932400.0
# 222587    MBB  22139300.0
# 222588    MBB  12640000.0
# 222589    MBB  14247500.0
#
# [222590 rows x 15 columns]

# %% [markdown]
# # Price and financialratio

# %%
[x["CategoryName"] for x in list_stocks["category"]]
# Out:
# ['Danh mục quan tâm',
#  'BDS',
#  'BDS - KCN',
#  'Bán lẻ',
#  'Bảo Hiểm',
#  'Cao su',
#  'Chứng Khoán',
#  'Cảng Biển & Vận Tải',
#  'Dầu khí',
#  'Dệt may',
#  'Ngân Hàng',
#  'Phân Bón & Hóa chất',
#  'Thép',
#  'Thủy sản',
#  'Trụ',
#  'Xây dựng',
#  'Điện gió',
#  'Đường, thực phẩm, gạo',
#  'Đầu tư công']

# %%
# symbols = list(filter(lambda x: x["CategoryName"] == "Ngân Hàng", list_stocks["category"]))[0][
#     "ListStockCode"
# ]
symbols = ["HDB"]
assert len(symbols) == 1

# %%
price_financialratio = pd.merge(
    prices[prices["symbol"].isin(symbols)],
    financialratio[financialratio["ticker"].isin(symbols)],
    left_on="symbol",
    right_on="ticker",
    how="inner",
)
price_financialratio = price_financialratio[
    (price_financialratio["date"] >= price_financialratio["quarter_start_time"])
    & (price_financialratio["date"] <= price_financialratio["quarter_end_time"])
]
if len(symbols) == 1:
    price_financialratio = price_financialratio.drop_duplicates(subset="date", keep="first")
price_financialratio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1230 entries, 19 to 28267
# Data columns (total 76 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   index                    1230 non-null   int64
#  1   date                     1230 non-null   datetime64[ns]
#  2   adjust                   1230 non-null   float64
#  3   close                    1230 non-null   float64
#  4   change_perc              1230 non-null   float64
#  5   avg                      1230 non-null   float64
#  6   volume_match             1230 non-null   float64
#  7   value_match              1230 non-null   float64
#  8   volume_reconcile         1230 non-null   float64
#  9   value_reconcile          1230 non-null   float64
#  10  open                     1230 non-null   float64
#  11  high                     1230 non-null   float64
#  12  low                      1230 non-null   float64
#  13  symbol                   1230 non-null   object
#  14  volume                   1230 non-null   float64
#  15  ticker                   1230 non-null   object
#  16  quarter                  1230 non-null   int64
#  17  year                     1230 non-null   int64
#  18  priceToEarning           1176 non-null   float64
#  19  priceToBook              1176 non-null   float64
#  20  valueBeforeEbitda        0 non-null      float64
#  21  dividend                 0 non-null      float64
#  22  roe                      1230 non-null   float64
#  23  roa                      1230 non-null   float64
#  24  daysReceivable           0 non-null      float64
#  25  daysInventory            0 non-null      float64
#  26  daysPayable              0 non-null      float64
#  27  ebitOnInterest           0 non-null      float64
#  28  earningPerShare          1230 non-null   float64
#  29  bookValuePerShare        1230 non-null   float64
#  30  interestMargin           1230 non-null   float64
#  31  nonInterestOnToi         1230 non-null   float64
#  32  badDebtPercentage        1230 non-null   float64
#  33  provisionOnBadDebt       1230 non-null   float64
#  34  costOfFinancing          1230 non-null   float64
#  35  equityOnTotalAsset       1230 non-null   float64
#  36  equityOnLoan             1230 non-null   float64
#  37  costToIncome             1230 non-null   float64
#  38  equityOnLiability        1230 non-null   float64
#  39  currentPayment           0 non-null      float64
#  40  quickPayment             0 non-null      float64
#  41  epsChange                1230 non-null   float64
#  42  ebitdaOnStock            0 non-null      float64
#  43  grossProfitMargin        0 non-null      float64
#  44  operatingProfitMargin    0 non-null      float64
#  45  postTaxMargin            0 non-null      float64
#  46  debtOnEquity             0 non-null      float64
#  47  debtOnAsset              0 non-null      float64
#  48  debtOnEbitda             0 non-null      float64
#  49  shortOnLongDebt          0 non-null      float64
#  50  assetOnEquity            1230 non-null   float64
#  51  capitalBalance           0 non-null      float64
#  52  cashOnEquity             0 non-null      float64
#  53  cashOnCapitalize         0 non-null      float64
#  54  cashCirculation          0 non-null      float64
#  55  revenueOnWorkCapital     0 non-null      float64
#  56  capexOnFixedAsset        0 non-null      float64
#  57  revenueOnAsset           0 non-null      float64
#  58  postTaxOnPreTax          0 non-null      float64
#  59  ebitOnRevenue            0 non-null      float64
#  60  preTaxOnEbit             0 non-null      float64
#  61  preProvisionOnToi        1230 non-null   float64
#  62  postTaxOnToi             1230 non-null   float64
#  63  loanOnEarnAsset          1230 non-null   float64
#  64  loanOnAsset              1230 non-null   float64
#  65  loanOnDeposit            1230 non-null   float64
#  66  depositOnEarnAsset       1230 non-null   float64
#  67  badDebtOnAsset           1230 non-null   float64
#  68  liquidityOnLiability     1230 non-null   float64
#  69  payableOnEquity          1230 non-null   float64
#  70  cancelDebt               1230 non-null   float64
#  71  ebitdaOnStockChange      0 non-null      float64
#  72  bookValuePerShareChange  1230 non-null   float64
#  73  creditGrowth             1230 non-null   float64
#  74  quarter_start_time       1230 non-null   datetime64[ns]
#  75  quarter_end_time         1230 non-null   datetime64[ns]
# dtypes: datetime64[ns](3), float64(68), int64(3), object(2)
# memory usage: 739.9+ KB

# %% [markdown]
# ## P/E & P/B

# %%
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go


price_financialratio["pe"] = (
    price_financialratio["close"] * 1000 / price_financialratio["earningPerShare"]
)
# sns.lineplot(data=price_financialratio, x="date", y="pe", hue="symbol")
fig = px.line(price_financialratio, x="date", y="pe", color="symbol")
# fig.update_layout(yaxis_range=[0,100])
fig.show()

# %%
if len(symbols) == 1:
    print(
        price_financialratio[
            (price_financialratio["date"] > "2022-07-01")
            & (price_financialratio["date"] < "2022-12-01")
        ]["pe"].min()
    )
# Out:
# 4.682274247491639

# %%
price_financialratio["pb"] = (
    price_financialratio["close"] * 1000 / price_financialratio["bookValuePerShare"]
)
# sns.lineplot(data=price_financialratio, x="date", y="pb", hue="symbol")
fig = px.line(price_financialratio, x="date", y="pb", color='symbol')
fig.show()

# %%
if len(symbols) == 1:
    fair_pb = 1.3
    filtered_date = price_financialratio[
        (price_financialratio["date"] > "2022-07-01")
        & (price_financialratio["date"] < "2022-12-01")
    ]
    row = filtered_date.loc[filtered_date["pb"].idxmin()]

    print("Giá fair:", ((fair_pb) / row["pb"]) * row["close"])
    print("Tăng % từ đáy: ", ((fair_pb - row["pb"]) / row["pb"]) * 100)
# Out:
# Giá fair: 28.702700000000004
# Tăng % từ đáy:  44.96313131313132
